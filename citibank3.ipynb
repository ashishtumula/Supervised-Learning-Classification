# %%
# To enable plotting graphs in Jupyter notebook. 
# This should always be the first step before importing the other libraries
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
from sklearn.preprocessing import Imputer
from sklearn.metrics import accuracy_score
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.naive_bayes import MultinomialNB

# %%
import os
os.chdir('C:/Users/ASHISH/Desktop/CLASSIFICATION-SUPERVISED LEARNING')

# %%
# Read the Wisconsin Breast Cancer Dataset
data1 = pd.read_csv("train_1.csv")#train1
data2 = pd.read_csv("train_2.csv")#train2
data3 = pd.read_csv('train_3.csv')#train3
test_df = pd.read_csv("test.csv")

# %%
train_df = pd.merge(data1,data2,on = 'Ref.No')

# %%
train_df1 = pd.merge(train_df,data3,on = "Ref.No")

# %%
train_df1.head()
# Out:
#    Ref.No      X1  X2  X3  X4  X5  X6  X7  Y  X8  ...      X14    X15    X16  \
# 0   22203  320000   2   1   2  27   1   2  1   2  ...    41370  40694  39606
# 1    1288  470000   1   2   1  41  -2  -2  0  -2  ...    32463  20621  13711
# 2   11822   20000   1   2   2  25   1   2  0   0  ...    18921  19297  18926
# 3   15085   80000   1   3   1  41   0   0  1   0  ...    60311  62471  21071
# 4    6192   30000   1   1   2  30   1  -2  1  -2  ...        0      0      0
#
#      X17    X18    X19   X20    X21   X22    X23
# 0  38680   2000   1500  2000   1500  1500      0
# 1   8294  12300  32520    34     68  8334  45684
# 2  17717   1264   1249   625    700  1000   1000
# 3   2099   3008   3000  5000  10000  2099      0
# 4      0      0      0     0      0     0      0
#
# [5 rows x 25 columns]

# %%
train_df1.shape
# Out:
# (21600, 25)

# %%
train_df1.dtypes
# Out:
# Ref.No    int64
# X1        int64
# X2        int64
# X3        int64
# X4        int64
# X5        int64
# X6        int64
# X7        int64
# Y         int64
# X8        int64
# X9        int64
# X10       int64
# X11       int64
# X12       int64
# X13       int64
# X14       int64
# X15       int64
# X16       int64
# X17       int64
# X18       int64
# X19       int64
# X20       int64
# X21       int64
# X22       int64
# X23       int64
# dtype: object

# %%
train_df1.describe().T
# Out:
#           count           mean            std       min       25%       50%  \
# Ref.No  21600.0   12000.773750    6931.541584       1.0   6008.75   12001.5
# X1      21600.0  165235.818519  129013.755215   10000.0  50000.00  140000.0
# X2      21600.0       1.626991       0.483616       1.0      1.00       2.0
# X3      21600.0       1.845926       0.781139       0.0      1.00       2.0
# X4      21600.0       1.558704       0.522008       0.0      1.00       2.0
# X5      21600.0      35.382361       9.266769      21.0     28.00      34.0
# X6      21600.0      -0.002917       1.126164      -2.0     -1.00       0.0
# X7      21600.0      -0.124028       1.201892      -2.0     -1.00       0.0
# Y       21600.0       0.223796       0.416797       0.0      0.00       0.0
# X8      21600.0      -0.157176       1.203906      -2.0     -1.00       0.0
# X9      21600.0      -0.214213       1.165579      -2.0     -1.00       0.0
# ...

# %%
train_df1.groupby(["Y"]).count()
# Out:
#    Ref.No     X1     X2     X3     X4     X5     X6     X7     X8     X9  \
# Y
# 0   16766  16766  16766  16766  16766  16766  16766  16766  16766  16766
# 1    4834   4834   4834   4834   4834   4834   4834   4834   4834   4834
#
#    ...      X14    X15    X16    X17    X18    X19    X20    X21    X22    X23
# Y  ...
# 0  ...    16766  16766  16766  16766  16766  16766  16766  16766  16766  16766
# 1  ...     4834   4834   4834   4834   4834   4834   4834   4834   4834   4834
#
# [2 rows x 24 columns]

# %%
train_df1_feature = train_df1.drop(labels= "Y" , axis = 1)

# %%
train_df1_feature
# Out:
#        Ref.No      X1  X2  X3  X4  X5  X6  X7  X8  X9  ...       X14     X15  \
# 0       22203  320000   2   1   2  27   1   2   2   2  ...     41370   40694
# 1        1288  470000   1   2   1  41  -2  -2  -2  -2  ...     32463   20621
# 2       11822   20000   1   2   2  25   1   2   0   0  ...     18921   19297
# 3       15085   80000   1   3   1  41   0   0   0   0  ...     60311   62471
# 4        6192   30000   1   1   2  30   1  -2  -2  -2  ...         0       0
# 5       12894  320000   2   2   1  39   0   0   0   0  ...    131816  120761
# 6        2279   50000   2   3   1  37   2   0   0   0  ...     40352   41183
# 7        1282  360000   1   1   2  34   1  -2  -2  -2  ...         0       0
# 8       13334   50000   2   1   1  25   0   0   0   0  ...     13008   12540
# 9       15251   30000   2   2   1  45   2   0   0   0  ...     31237   13511
# 10      12165  130000   2   3   1  41   0   0   0   0  ...    128599  131454
# ...

# %%
train_df1_feature_z = train_df1_feature.apply(zscore)

# %%
train_df1_feature_z
# Out:
#          Ref.No        X1        X2        X3        X4        X5        X6  \
# 0      1.471889  1.199622  0.771310 -1.082964  0.845402 -0.904582  0.890581
# 1     -1.545547  2.362316 -1.296495  0.197247 -1.070322  0.606227 -1.773392
# 2     -0.025792 -1.125765 -1.296495  0.197247  0.845402 -1.120412  0.890581
# 3      0.444966 -0.660688 -1.296495  1.477459 -1.070322  0.606227  0.002590
# 4     -0.838040 -1.048252 -1.296495 -1.082964  0.845402 -0.580837  0.890581
# 5      0.128867  1.199622  0.771310  0.197247 -1.070322  0.390397  0.002590
# 6     -1.402574 -0.893226  0.771310  1.477459 -1.070322  0.174567  1.778572
# 7     -1.546412  1.509674 -1.296495 -1.082964  0.845402 -0.149177  0.890581
# 8      0.192346 -0.893226  0.771310 -1.082964 -1.070322 -1.120412  0.002590
# 9      0.468915 -1.048252  0.771310  0.197247 -1.070322  1.037887  1.778572
# 10     0.023693 -0.273123  0.771310  1.477459 -1.070322  0.606227  0.002590
# ...

# %%
columns = ['Ref.No', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'Y', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15','16','17','18','19','20','21','22','23']

# %%
data_test = pd.DataFrame(datatest1, columns=columns)

# %%
data_test
# Out:
#       Ref.No      X1  X2  X3  X4  X5  X6  X7   Y  X8 ...     X14     X15  16  \
# 0      17083   50000   2   1   2  25   0   0 NaN   0 ...   40002   38008 NaN
# 1       3494  120000   2   2   2  24   0   0 NaN   0 ...   11761    6761 NaN
# 2      21945  120000   2   2   2  27   1  -2 NaN  -1 ...    2382       0 NaN
# 3       3499   60000   1   1   2  28   0  -1 NaN   0 ...   13421    9900 NaN
# 4      18973  100000   2   1   2  28   3   2 NaN   0 ...   49899   53407 NaN
# 5       3249  290000   2   2   1  34   0   0 NaN   0 ...   18231   18593 NaN
# 6      22537  130000   2   2   1  48   2   2 NaN   2 ...  109965  110797 NaN
# 7       9577   20000   1   2   1  40   1   2 NaN   0 ...   18867   19253 NaN
# 8       3699  360000   1   2   2  28   1  -2 NaN  -2 ...       0       0 NaN
# 9      19542  170000   2   1   1  38  -1  -1 NaN  -2 ...       0       0 NaN
# 10     15567   50000   1   3   2  40   0   0 NaN   0 ...   46616   48872 NaN
# ...

# %%
data_test.shape
# Out:
# (2399, 25)

# %%
test_df.dtypes
# Out:
# Ref.No      int64
# X1          int64
# X2          int64
# X3          int64
# X4          int64
# X5          int64
# X6          int64
# X7          int64
# X8          int64
# X9          int64
# X10         int64
# X11         int64
# X12         int64
# X13         int64
# X14         int64
# X15         int64
# X16         int64
# X17         int64
# X18         int64
# X19         int64
# X20         int64
# X21         int64
# X22         int64
# X23         int64
# Y         float64
# dtype: object

# %%
test_df.head()
# Out:
#    Ref.No      X1  X2  X3  X4  X5  X6  X7  X8  X9 ...    X15    X16    X17  \
# 0   17083   50000   2   1   2  25   0   0   0   0 ...  38008  31898  20154
# 1    3494  120000   2   2   2  24   0   0   0   0 ...   6761   7189   1087
# 2   21945  120000   2   2   2  27   1  -2  -1  -1 ...      0      0      0
# 3    3499   60000   1   1   2  28   0  -1   0   0 ...   9900    310    160
# 4   18973  100000   2   1   2  28   3   2   0   0 ...  53407  51951  53195
#
#     X18    X19   X20   X21   X22    X23   Y
# 0  2000   5040  8034  3029  5000  49436 NaN
# 1  1400   1000     0  1000  1087    801 NaN
# 2     0   2382     0     0     0      0 NaN
# 3  6000  10000   900   310     0   3400 NaN
# 4     0   1831  4339     0  2083   1939 NaN
#
# [5 rows x 25 columns]

# %%
data2_feature_z = data_test.apply(zscore)

# %%
data1_labels = train_df1["Y"]

# %%
data2_labels = test_df["Y"]

# %%
X1 = np.array(train_df1_featurez)
Y1 = np.array(data_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-71fa1f0de4a5> in <module>()
# ----> 1 X1 = np.array(train_df1_featurez)
#       2 Y1 = np.array(data_labels)
#
# NameError: name 'np' is not defined
