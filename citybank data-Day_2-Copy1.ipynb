# %%
# To enable plotting graphs in Jupyter notebook. 
# This should always be the first step before importing the other libraries
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
from sklearn.preprocessing import Imputer
from sklearn.metrics import accuracy_score
import seaborn as sns
# Models
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn.linear_model import Perceptron
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier

# Cross-validation
from sklearn.model_selection import KFold #for K-fold cross validation
from sklearn.model_selection import cross_val_score #score evaluation
from sklearn.model_selection import cross_val_predict #prediction
from sklearn.model_selection import cross_validate

# GridSearchCV
from sklearn.model_selection import GridSearchCV

#Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis,gaussian_process

#Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics

#Visualization
import matplotlib as mpl
import matplotlib.pylab as pylab
from pandas.tools.plotting import scatter_matrix

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from imblearn.over_sampling import SMOTE

# %%
import os
os.chdir('C:/Users/ASHISH/Desktop/CLASSIFICATION-SUPERVISED LEARNING')

# %%
# Read the Wisconsin Breast Cancer Dataset
datatrain1 = pd.read_csv("train_1.csv")
datatrain2 = pd.read_csv("train_2.csv")
datatest1 = pd.read_csv("test.csv")

# %%
datatrain1.head()
# Out:
#    Ref.No      X1  X2  X3  X4  X5  X6  X7  Y
# 0   22203  320000   2   1   2  27   1   2  1
# 1    1288  470000   1   2   1  41  -2  -2  0
# 2   11822   20000   1   2   2  25   1   2  0
# 3   15085   80000   1   3   1  41   0   0  1
# 4    6192   30000   1   1   2  30   1  -2  1

# %%
datatrain2.head()
# Out:
#    Ref.No  X8  X9  X10  X11    X12    X13    X14    X15
# 0   22203   2   2    2    2  43243  42537  41370  40694
# 1    1288  -2  -2   -2   -1  13780  12242  32463  20621
# 2   11822   0   0    0    0  20415  18266  18921  19297
# 3   15085   0   0    0   -1  76015  77582  60311  62471
# 4    6192  -2  -2   -2   -2      0      0      0      0

# %%
data_train = pd.merge(datatrain1, datatrain2, on=['Ref.No'])

# %%
data_train.head()
# Out:
#    Ref.No      X1  X2  X3  X4  X5  X6  X7  Y  X8  X9  X10  X11    X12    X13  \
# 0   22203  320000   2   1   2  27   1   2  1   2   2    2    2  43243  42537
# 1    1288  470000   1   2   1  41  -2  -2  0  -2  -2   -2   -1  13780  12242
# 2   11822   20000   1   2   2  25   1   2  0   0   0    0    0  20415  18266
# 3   15085   80000   1   3   1  41   0   0  1   0   0    0   -1  76015  77582
# 4    6192   30000   1   1   2  30   1  -2  1  -2  -2   -2   -2      0      0
#
#      X14    X15
# 0  41370  40694
# 1  32463  20621
# 2  18921  19297
# 3  60311  62471
# 4      0      0

# %%
data_train.shape
# Out:
# (21600, 17)

# %%
data_train.dtypes
# Out:
# Ref.No    int64
# X1        int64
# X2        int64
# X3        int64
# X4        int64
# X5        int64
# X6        int64
# X7        int64
# Y         int64
# X8        int64
# X9        int64
# X10       int64
# X11       int64
# X12       int64
# X13       int64
# X14       int64
# X15       int64
# dtype: object

# %%
data_train.describe().T
# Out:
#           count           mean            std       min       25%       50%  \
# Ref.No  21600.0   12000.773750    6931.541584       1.0   6008.75   12001.5
# X1      21600.0  165235.818519  129013.755215   10000.0  50000.00  140000.0
# X2      21600.0       1.626991       0.483616       1.0      1.00       2.0
# X3      21600.0       1.845926       0.781139       0.0      1.00       2.0
# X4      21600.0       1.558704       0.522008       0.0      1.00       2.0
# X5      21600.0      35.382361       9.266769      21.0     28.00      34.0
# X6      21600.0      -0.002917       1.126164      -2.0     -1.00       0.0
# X7      21600.0      -0.124028       1.201892      -2.0     -1.00       0.0
# Y       21600.0       0.223796       0.416797       0.0      0.00       0.0
# X8      21600.0      -0.157176       1.203906      -2.0     -1.00       0.0
# X9      21600.0      -0.214213       1.165579      -2.0     -1.00       0.0
# ...

# %%
data_train.groupby(["Y"]).count()
# Out:
#    Ref.No     X1     X2     X3     X4     X5     X6     X7     X8     X9  \
# Y
# 0   16766  16766  16766  16766  16766  16766  16766  16766  16766  16766
# 1    4834   4834   4834   4834   4834   4834   4834   4834   4834   4834
#
#      X10    X11    X12    X13    X14    X15
# Y
# 0  16766  16766  16766  16766  16766  16766
# 1   4834   4834   4834   4834   4834   4834

# %%
data_train_feature = data_train.drop(labels= "Y" , axis = 1)

# %%
data_train_feature_z = data_train_feature.apply(zscore)

# %%
columns = ['Ref.No', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'Y', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15']

# %%
data_test = pd.DataFrame(datatest1, columns=columns)

# %%
data_test.head()
# Out:
#    Ref.No      X1  X2  X3  X4  X5  X6  X7   Y  X8  X9  X10  X11    X12    X13  \
# 0   17083   50000   2   1   2  25   0   0 NaN   0   0    0    0  45342  44719
# 1    3494  120000   2   2   2  24   0   0 NaN   0   0    0   -1  11296  12200
# 2   21945  120000   2   2   2  27   1  -2 NaN  -1  -1   -2   -2      0      0
# 3    3499   60000   1   1   2  28   0  -1 NaN   0   0   -1    2   2295   5293
# 4   18973  100000   2   1   2  28   3   2 NaN   0   0    2    0  49961  48856
#
#      X14    X15
# 0  40002  38008
# 1  11761   6761
# 2   2382      0
# 3  13421   9900
# 4  49899  53407

# %%
data_test.shape
# Out:
# (2399, 17)

# %%
data_test.dtypes
# Out:
# Ref.No      int64
# X1          int64
# X2          int64
# X3          int64
# X4          int64
# X5          int64
# X6          int64
# X7          int64
# Y         float64
# X8          int64
# X9          int64
# X10         int64
# X11         int64
# X12         int64
# X13         int64
# X14         int64
# X15         int64
# dtype: object

# %%
data_test_feature = data_test.drop(labels= "Y" , axis = 1)

# %%
data_test_feature_z = data_test_feature.apply(zscore)

# %%
data_train_labels = data_train["Y"]

# %%
data_test_labels = data_test["Y"]

# %%
X1 = np.array(data_train_feature_z)

# %%
Y1 = np.array(data_train_labels)

# %%
X2 = np.array(data_test_feature_z)

# %%
X_Train = X1
Y_Train = Y1
X_Test = X2

# %%
X_Train.shape, Y_Train.shape, X_Test.shape
# Out:
# ((21600, 16), (21600,), (2399, 16))

# %%
# Call Nearest Neighbour algorithm
#from sklearn.neighbors import KNeighborsClassifier
NNH = KNeighborsClassifier(n_neighbors = 19)
NNH.fit(X_Train, Y_Train)
predicted_labels = NNH.predict(X_Test)
print(predicted_labels)
# Out:
# [0 0 0 ... 1 0 0]

# %%
sub = pd.DataFrame(pd.read_csv("test.csv")['Ref.No'])
for i in range(0, len(sub)):
    sub["Ref.No"][i] = i+1
sub['Y'] = predicted_labels
sub.to_csv("sample_submission101.csv", index = False)
sub.head()
# Out:
#    Ref.No  Y
# 0       1  0
# 1       2  0
# 2       3  0
# 3       4  0
# 4       5  1
